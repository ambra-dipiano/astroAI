# %%
import pandas as pd

infofile = f'/data01/homes/dipiano/E4/irf_random/crab/map_200x200_randomEXP/merged_simulator_data.dat'
infodata = pd.read_csv(infofile, sep=' ', header=0).sort_values(by=['seed'])
infodata.head()
# Out:
#              name  seed  start  stop  duration   source_ra  source_dec  \
# 15000  crab_00001     1      0   100       100   57.265654   30.447065
# 15001  crab_00002     2      0   100       100   98.177801   40.950640
# 15002  crab_00003     3      0   100       100   76.984211  -66.348920
# 15003  crab_00004     4      0   100       100  125.495725  -44.424075
# 15004  crab_00005     5      0   100       100  214.162576   42.736282
#
#          point_ra  point_dec    offset                   irf  fov  sim_time
# 15000   57.253328  30.454269  0.012838  North_z40_S_0.5h_LST  2.5  7.322825
# 15001   98.016897  41.081760  0.178695   North_z60_N_50h_LST  2.5  6.762409
# 15002   78.358890 -67.138246  0.957894    North_z40_N_5h_LST  2.5  7.029939
# 15003  126.479118 -43.608941  1.079135      North_z40_5h_LST  2.5  7.074566
# 15004  215.790559  43.357500  1.342109      North_z20_5h_LST  2.5  7.087336
