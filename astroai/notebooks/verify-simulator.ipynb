# %%
from IPython.display import Image

im1 = Image(filename='/data01/homes/dipiano/E4/test/map/crab_001_map.png')
im2 = Image(filename='/data01/homes/dipiano/E4/test/map/crab_003_map.png')
im3 = Image(filename='/data01/homes/dipiano/E4/test/map/crab_006_map.png')
im4 = Image(filename='/data01/homes/dipiano/E4/test/map/crab_009_map.png')

display(im1, im2, im3, im4)
